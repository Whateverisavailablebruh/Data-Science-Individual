# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
url= "C://Users/12368/OneDrive - UBC/DATA/Unicorn/unicorns till sep 2022.csv"
data= pd.read_csv(url)
data['Date Joined'] = pd.to_datetime(data['Date Joined'])
data
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $140  2017-04-07          China
# 1                  SpaceX           $127  2012-12-01  United States
# 2                   SHEIN           $100  2018-07-03          China
# 3                  Stripe            $95  2014-01-23  United States
# 4                   Canva            $40  2018-01-08      Australia
# ...                   ...            ...         ...            ...
# 1181          LeadSquared             $1  2022-06-21          India
# 1182            FourKites             $1  2022-06-21  United States
# 1183          VulcanForms             $1  2022-07-05  United States
# 1184          SingleStore             $1  2022-07-12  United States
# 1185  Unstoppable Domains             $1  2022-07-27  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
USA= list()
China= list()
Britain= list()
India= list()
Indonesia= list()
Germany= list()
Sing= list()
Japan= list()
Korea= list()
France= list()
Pacific= list()
Europe= list()
Israel= list()

# %%
data['Country'].unique()
# Out:
# array(['China', 'United States', 'Australia', 'United Kingdom', 'Bahamas',
#        'India', 'Indonesia', 'Germany', 'Turkey', 'Hong Kong',
#        'Seychelles', 'Sweden', 'Mexico', 'Estonia', 'Canada',
#        'Netherlands', 'France', 'Israel', 'Finland', 'Colombia',
#        'Belgium', 'Brazil', 'South Korea', 'Denmark', 'Switzerland',
#        'Lithuania', 'Austria', 'Ireland', 'Singapore', 'Vietnam',
#        'United Arab Emirates', 'Argentina', 'Spain', 'Japan',
#        'Luxembourg', 'Nigeria', 'Philippines', 'Croatia', 'Senegal',
#        'Malaysia', 'Bermuda', 'Norway', 'South Africa', 'Ecuador',
#        'Chile', 'Thailand', 'Czech Republic', 'Italy'], dtype=object)

# %%
US= data.loc[(data['Country'] == 'United States') & (data['Date Joined'] > '1-1-2018')]
CN= data.loc[((data['Country'] == 'China') | (data['Country'] == 'Hong Kong')) & (data['Date Joined'] > '1-1-2018')]
UK= data.loc[(data['Country'] == 'United Kingdom') & (data['Date Joined'] > '1-1-2018')]
IND= data.loc[(data['Country'] == 'India') & (data['Date Joined'] > '1-1-2018')]
IN= data.loc[(data['Country'] == 'Indonesia') & (data['Date Joined'] > '1-1-2018')]
GER= data.loc[(data['Country'] == 'Germany') & (data['Date Joined'] > '1-1-2018')]
SIN= data.loc[(data['Country'] == 'Singapore') & (data['Date Joined'] > '1-1-2018')]
JP= data.loc[(data['Country'] == 'Japan') & (data['Date Joined'] > '1-1-2018')]
SK= data.loc[(data['Country'] == 'South Korea') & (data['Date Joined'] > '1-1-2018')]
FR= data.loc[(data['Country'] == 'France') & (data['Date Joined'] > '1-1-2018')]
Swe= data.loc[(data['Country'] == 'Sweden') & (data['Date Joined'] > '1-1-2018')]
ITL= data.loc[(data['Country'] == 'Italy') & (data['Date Joined'] > '1-1-2018')]
CR= data.loc[(data['Country'] == 'Czech Republic') & (data['Date Joined'] > '1-1-2018')]
NOR= data.loc[(data['Country'] == 'Norway') & (data['Date Joined'] > '1-1-2018')]
MAL= data.loc[(data['Country'] == 'Malaysia') & (data['Date Joined'] > '1-1-2018')]
cro= data.loc[(data['Country'] == 'Croatia') & (data['Date Joined'] > '1-1-2018')]
phi= data.loc[(data['Country'] == 'Philippines') & (data['Date Joined'] > '1-1-2018')]
lex= data.loc[(data['Country'] == 'Luxembourg') & (data['Date Joined'] > '1-1-2018')]
spa= data.loc[(data['Country'] == 'Spain') & (data['Date Joined'] > '1-1-2018')]
den= data.loc[(data['Country'] == 'Denmark') & (data['Date Joined'] > '1-1-2018')]
swi= data.loc[(data['Country'] == 'Switzerland') & (data['Date Joined'] > '1-1-2018')]
bel= data.loc[(data['Country'] == 'Belgium') & (data['Date Joined'] > '1-1-2018')]
fin= data.loc[(data['Country'] == 'Finland') & (data['Date Joined'] > '1-1-2018')]
Ir= data.loc[(data['Country'] == 'Ireland') & (data['Date Joined'] > '1-1-2018')]

# %%
Murica= len(US.index)
Cina= len(CN.index)
Britan= len(UK.index)
Inia= len(IND.index)
Inosia= len(IN.index)
Gerany= len(GER.index)
Sinapo= len(SIN.index)
Japa= len(JP.index)
Koea= len(SK.index)
Franc= len(FR.index)
SWD= len(Swe.index)
Ital= len(ITL.index)
CZE= len(CR.index)
NORAY=len(NOR.index)
MALAYA= len(MAL.index)
CROIA= len(cro.index)
PHIL= len(phi.index)
Luxo= len(lex.index)
Spai=len(spa.index)
Denma= len(den.index)
SWISS= len(swi.index)
BELGI= len(bel.index)
Finla= len(fin.index)
Irich= len(Ir.index)

# %%
y= [Murica, Cina, Britan, Inia, Inosia, Gerany, Sinapo, Japa, Koea, Franc]
y
x= ["US", "CN/HK", "UK", "Ind", "Indo", "Ger", "Sin", "Jp", "Kr", "Fr"]
x
# Out:
# ['US', 'CN/HK', 'UK', 'Ind', 'Indo', 'Ger', 'Sin', 'Jp', 'Kr', 'Fr']

# %%
plt.bar(x,y, color='maroon', width= 0.4)
plt.tight_layout
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
y
# Out:
# [595, 128, 39, 66, 6, 28, 13, 6, 14, 21]

# %%
US= data.loc[(data['Country'] == 'United States') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
CN= data.loc[((data['Country'] == 'China') | (data['Country'] == 'Hong Kong')) & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
UK= data.loc[(data['Country'] == 'United Kingdom') & (data['Date Joined'] > '1-1-2018')& (data['Date Joined'] < '1-1-2019')]
IND= data.loc[(data['Country'] == 'India') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
IN= data.loc[(data['Country'] == 'Indonesia') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
GER= data.loc[(data['Country'] == 'Germany') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
SIN= data.loc[(data['Country'] == 'Singapore') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
JP= data.loc[(data['Country'] == 'Japan') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
SK= data.loc[(data['Country'] == 'South Korea') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
FR= data.loc[(data['Country'] == 'France') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
Swe= data.loc[(data['Country'] == 'Sweden') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
ITL= data.loc[(data['Country'] == 'Italy') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
CR= data.loc[(data['Country'] == 'Czech Republic') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
NOR= data.loc[(data['Country'] == 'Norway') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
MAL= data.loc[(data['Country'] == 'Malaysia') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
cro= data.loc[(data['Country'] == 'Croatia') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
phi= data.loc[(data['Country'] == 'Philippines') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
lex= data.loc[(data['Country'] == 'Luxembourg') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
spa= data.loc[(data['Country'] == 'Spain') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
den= data.loc[(data['Country'] == 'Denmark') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
swi= data.loc[(data['Country'] == 'Switzerland') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
bel= data.loc[(data['Country'] == 'Belgium') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
fin= data.loc[(data['Country'] == 'Finland') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
Ir= data.loc[(data['Country'] == 'Ireland') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]
Is= data.loc[(data['Country'] == 'Israel') & (data['Date Joined'] > '1-1-2018') & (data['Date Joined'] < '1-1-2019')]

# %%
Murica= len(US.index)
Cina= len(CN.index)
Britan= len(UK.index)
Inia= len(IND.index)
Inosia= len(IN.index)
Gerany= len(GER.index)
Sinapo= len(SIN.index)
Japa= len(JP.index)
Koea= len(SK.index)
Franc= len(FR.index)
SWD= len(Swe.index)
Ital= len(ITL.index)
CZE= len(CR.index)
NORAY=len(NOR.index)
MALAYA= len(MAL.index)
CROIA= len(cro.index)
PHIL= len(phi.index)
Luxo= len(lex.index)
Spai=len(spa.index)
Denma= len(den.index)
SWISS= len(swi.index)
BELGI= len(bel.index)
Finla= len(fin.index)
Irich= len(Ir.index)
Isa= len(Is.index)

# %%
y= [Murica, Cina, Britan, Inia, Inosia, Gerany, Sinapo, Japa, Koea, Franc]
y
x= ["US", "CN/HK", "UK", "Ind", "Indo", "Ger", "Sin", "Jp", "Kr", "Fr"]
x
plt.bar(x,y, color='maroon', width= 0.4)
plt.title('2018')
plt.tight_layout
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
USA.append(Murica)
China.append(Cina)
Britain.append(Britan)
India.append(Inia)
Indonesia.append(Inosia)
Germany.append(Gerany)
Sing.append(Sinapo)
Japan.append(Japa)
Korea.append(Koea)
France.append(Franc)
Pacific.append(Cina+Inia+Inosia+Sinapo+Japa+Koea+PHIL+MALAYA)
Europe.append(Britan+Gerany+NORAY+Franc+SWISS+Ital+CZE+Denma+Finla+Luxo+Spai+BELGI+CROIA+Irich)
Israel.append(Isa)

# %%
US= data.loc[(data['Country'] == 'United States') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
CN= data.loc[((data['Country'] == 'China') | (data['Country'] == 'Hong Kong')) & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
UK= data.loc[(data['Country'] == 'United Kingdom') & (data['Date Joined'] > '1-1-2019')& (data['Date Joined'] < '1-1-2020')]
IND= data.loc[(data['Country'] == 'India') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
IN= data.loc[(data['Country'] == 'Indonesia') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
GER= data.loc[(data['Country'] == 'Germany') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
SIN= data.loc[(data['Country'] == 'Singapore') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
JP= data.loc[(data['Country'] == 'Japan') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
SK= data.loc[(data['Country'] == 'South Korea') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
FR= data.loc[(data['Country'] == 'France') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
Swe = data.loc[(data['Country'] == 'Sweden') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
ITL = data.loc[
    (data['Country'] == 'Italy') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
CR = data.loc[
    (data['Country'] == 'Czech Republic') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
NOR = data.loc[(data['Country'] == 'Norway') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
MAL = data.loc[
    (data['Country'] == 'Malaysia') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
cro = data.loc[(data['Country'] == 'Croatia') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
phi = data.loc[
    (data['Country'] == 'Philippines')& (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
lex = data.loc[
    (data['Country'] == 'Luxembourg') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
spa = data.loc[(data['Country'] == 'Spain') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
den = data.loc[(data['Country'] == 'Denmark') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
swi = data.loc[
    (data['Country'] == 'Switzerland') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
bel = data.loc[(data['Country'] == 'Belgium') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
fin = data.loc[(data['Country'] == 'Finland') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
Ir = data.loc[(data['Country'] == 'Ireland') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]
Is= data.loc[(data['Country'] == 'Israel') & (data['Date Joined'] > '1-1-2019') & (data['Date Joined'] < '1-1-2020')]

# %%
Murica= len(US.index)
Cina= len(CN.index)
Britan= len(UK.index)
Inia= len(IND.index)
Inosia= len(IN.index)
Gerany= len(GER.index)
Sinapo= len(SIN.index)
Japa= len(JP.index)
Koea= len(SK.index)
Franc= len(FR.index)
SWD= len(Swe.index)
Ital= len(ITL.index)
CZE= len(CR.index)
NORAY=len(NOR.index)
MALAYA= len(MAL.index)
CROIA= len(cro.index)
PHIL= len(phi.index)
Luxo= len(lex.index)
Spai=len(spa.index)
Denma= len(den.index)
SWISS= len(swi.index)
BELGI= len(bel.index)
Finla= len(fin.index)
Irich= len(Ir.index)
Isa= len(Is.index)

# %%
y= [Murica, Cina, Britan, Inia, Inosia, Gerany, Sinapo, Japa, Koea, Franc]
y
x= ["US", "CN/HK", "UK", "Ind", "Indo", "Ger", "Sin", "Jp", "Kr", "Fr"]
x
plt.bar(x,y, color='maroon', width= 0.4)
plt.title("2019")
plt.tight_layout
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
USA.append(Murica)
China.append(Cina)
Britain.append(Britan)
India.append(Inia)
Indonesia.append(Inosia)
Germany.append(Gerany)
Sing.append(Sinapo)
Japan.append(Japa)
Korea.append(Koea)
France.append(Franc)
Pacific.append(Cina+Inia+Inosia+Sinapo+Japa+Koea+PHIL+MALAYA)
Europe.append(Britan+Gerany+NORAY+Franc+SWISS+Ital+CZE+Denma+Finla+Luxo+Spai+BELGI+CROIA+Irich)
Israel.append(Isa)

# %%
US = data.loc[
    (data['Country'] == 'United States') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

CN = data.loc[((data['Country'] == 'China') | (data['Country'] == 'Hong Kong')) & (data['Date Joined'] > '1-1-2020') & (
            data['Date Joined'] < '1-1-2021')]

UK = data.loc[
    (data['Country'] == 'United Kingdom') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

IND = data.loc[(data['Country'] == 'India') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

IN = data.loc[
    (data['Country'] == 'Indonesia') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

GER = data.loc[(data['Country'] == 'Germany') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

SIN = data.loc[
    (data['Country'] == 'Singapore') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

JP = data.loc[(data['Country'] == 'Japan') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

SK = data.loc[
    (data['Country'] == 'South Korea') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

FR = data.loc[(data['Country'] == 'France') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

Swe= data.loc[(data['Country'] == 'Sweden') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
ITL= data.loc[(data['Country'] == 'Italy') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
CR= data.loc[(data['Country'] == 'Czech Republic') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
NOR= data.loc[(data['Country'] == 'Norway') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
MAL= data.loc[(data['Country'] == 'Malaysia') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
cro= data.loc[(data['Country'] == 'Croatia') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
phi= data.loc[(data['Country'] == 'Philippines') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
lex= data.loc[(data['Country'] == 'Luxembourg') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
spa= data.loc[(data['Country'] == 'Spain') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
den= data.loc[(data['Country'] == 'Denmark') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
swi= data.loc[(data['Country'] == 'Switzerland') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
bel= data.loc[(data['Country'] == 'Belgium') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
fin= data.loc[(data['Country'] == 'Finland') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
Ir= data.loc[(data['Country'] == 'Ireland') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]
Is= data.loc[(data['Country'] == 'Israel') & (data['Date Joined'] > '1-1-2020') & (data['Date Joined'] < '1-1-2021')]

Murica = len(US.index)
Cina = len(CN.index)
Britan = len(UK.index)
Inia = len(IND.index)
Inosia = len(IN.index)
Gerany = len(GER.index)
Sinapo = len(SIN.index)
Japa = len(JP.index)
Koea = len(SK.index)
Franc = len(FR.index)
SWD= len(Swe.index)
Ital= len(ITL.index)
CZE= len(CR.index)
NORAY=len(NOR.index)
MALAYA= len(MAL.index)
CROIA= len(cro.index)
PHIL= len(phi.index)
Luxo= len(lex.index)
Spai=len(spa.index)
Denma= len(den.index)
SWISS= len(swi.index)
BELGI= len(bel.index)
Finla= len(fin.index)
Irich= len(Ir.index)
Isa= len(Is.index)
y = [Murica, Cina, Britan, Inia, Inosia, Gerany, Sinapo, Japa, Koea, Franc]
y
x = ["US", "CN/HK", "UK", "Ind", "Indo", "Ger", "Sin", "Jp", "Kr", "Fr"]
x
plt.bar(x, y, color='maroon', width=0.4)
plt.title("2020")
plt.tight_layout
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
USA.append(Murica)
China.append(Cina)
Britain.append(Britan)
India.append(Inia)
Indonesia.append(Inosia)
Germany.append(Gerany)
Sing.append(Sinapo)
Japan.append(Japa)
Korea.append(Koea)
France.append(Franc)
Pacific.append(Cina+Inia+Inosia+Sinapo+Japa+Koea+PHIL+MALAYA)
Europe.append(Britan+Gerany+NORAY+Franc+SWISS+Ital+CZE+Denma+Finla+Luxo+Spai+BELGI+CROIA+Irich)
Israel.append(Isa)

# %%
US = data.loc[
    (data['Country'] == 'United States') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

CN = data.loc[((data['Country'] == 'China') | (data['Country'] == 'Hong Kong')) & (data['Date Joined'] > '1-1-2021') & (
            data['Date Joined'] < '1-1-2022')]

UK = data.loc[
    (data['Country'] == 'United Kingdom') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

IND = data.loc[(data['Country'] == 'India') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

IN = data.loc[
    (data['Country'] == 'Indonesia') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

GER = data.loc[(data['Country'] == 'Germany') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

SIN = data.loc[
    (data['Country'] == 'Singapore') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

JP = data.loc[(data['Country'] == 'Japan') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

SK = data.loc[
    (data['Country'] == 'South Korea') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

FR = data.loc[(data['Country'] == 'France') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]

Swe= data.loc[(data['Country'] == 'Sweden')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
ITL= data.loc[(data['Country'] == 'Italy')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
CR= data.loc[(data['Country'] == 'Czech Republic')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
NOR= data.loc[(data['Country'] == 'Norway')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
MAL= data.loc[(data['Country'] == 'Malaysia')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
cro= data.loc[(data['Country'] == 'Croatia')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
phi= data.loc[(data['Country'] == 'Philippines')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
lex= data.loc[(data['Country'] == 'Luxembourg')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
spa= data.loc[(data['Country'] == 'Spain')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
den= data.loc[(data['Country'] == 'Denmark')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
swi= data.loc[(data['Country'] == 'Switzerland')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
bel= data.loc[(data['Country'] == 'Belgium')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
fin= data.loc[(data['Country'] == 'Finland')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
Ir= data.loc[(data['Country'] == 'Ireland')  & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
Is= data.loc[(data['Country'] == 'Israel') & (data['Date Joined'] > '1-1-2021') & (data['Date Joined'] < '1-1-2022')]
Murica = len(US.index)
Cina = len(CN.index)
Britan = len(UK.index)
Inia = len(IND.index)
Inosia = len(IN.index)
Gerany = len(GER.index)
Sinapo = len(SIN.index)
Japa = len(JP.index)
Koea = len(SK.index)
Franc = len(FR.index)
SWD= len(Swe.index)
Ital= len(ITL.index)
CZE= len(CR.index)
NORAY=len(NOR.index)
MALAYA= len(MAL.index)
CROIA= len(cro.index)
PHIL= len(phi.index)
Luxo= len(lex.index)
Spai=len(spa.index)
Denma= len(den.index)
SWISS= len(swi.index)
BELGI= len(bel.index)
Finla= len(fin.index)
Irich= len(Ir.index)
Isa= len(Is.index)
y = [Murica, Cina, Britan, Inia, Inosia, Gerany, Sinapo, Japa, Koea, Franc]
y
x = ["US", "CN/HK", "UK", "Ind", "Indo", "Ger", "Sin", "Jp", "Kr", "Fr"]
x
plt.bar(x, y, color='maroon', width=0.4)
plt.title("2021")
plt.tight_layout
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
USA.append(Murica)
China.append(Cina)
Britain.append(Britan)
India.append(Inia)
Indonesia.append(Inosia)
Germany.append(Gerany)
Sing.append(Sinapo)
Japan.append(Japa)
Korea.append(Koea)
France.append(Franc)
Pacific.append(Cina+Inia+Inosia+Sinapo+Japa+Koea+PHIL+MALAYA)
Europe.append(Britan+Gerany+NORAY+Franc+SWISS+Ital+CZE+Denma+Finla+Luxo+Spai+BELGI+CROIA+Irich)
Israel.append(Isa)

# %%
US = data.loc[(data['Country'] == 'United States') & (data['Date Joined'] > '1-1-2022')]
CN = data.loc[((data['Country'] == 'China') | (data['Country'] == 'Hong Kong')) & (data['Date Joined'] > '1-1-2022')]
UK = data.loc[(data['Country'] == 'United Kingdom') & (data['Date Joined'] > '1-1-2022')]
IND = data.loc[(data['Country'] == 'India') & (data['Date Joined'] > '1-1-2022')]
IN = data.loc[(data['Country'] == 'Indonesia') & (data['Date Joined'] > '1-1-2022')]
GER = data.loc[(data['Country'] == 'Germany') & (data['Date Joined'] > '1-1-2022')]
SIN = data.loc[(data['Country'] == 'Singapore') & (data['Date Joined'] > '1-1-2022')]
JP = data.loc[(data['Country'] == 'Japan') & (data['Date Joined'] > '1-1-2022')]
SK = data.loc[(data['Country'] == 'South Korea') & (data['Date Joined'] > '1-1-2022')]
FR = data.loc[(data['Country'] == 'France') & (data['Date Joined'] > '1-1-2022')]
Swe= data.loc[(data['Country'] == 'Sweden') & (data['Date Joined'] > '1-1-2022')]
ITL= data.loc[(data['Country'] == 'Italy') & (data['Date Joined'] > '1-1-2022')]
CR= data.loc[(data['Country'] == 'Czech Republic') & (data['Date Joined'] > '1-1-2022')]
NOR= data.loc[(data['Country'] == 'Norway') & (data['Date Joined'] > '1-1-2022')]
MAL= data.loc[(data['Country'] == 'Malaysia') & (data['Date Joined'] > '1-1-2022')]
cro= data.loc[(data['Country'] == 'Croatia') & (data['Date Joined'] > '1-1-2022')]
phi= data.loc[(data['Country'] == 'Philippines') & (data['Date Joined'] > '1-1-2022')]
lex= data.loc[(data['Country'] == 'Luxembourg') & (data['Date Joined'] > '1-1-2022')]
spa= data.loc[(data['Country'] == 'Spain') & (data['Date Joined'] > '1-1-2022')]
den= data.loc[(data['Country'] == 'Denmark') & (data['Date Joined'] > '1-1-2022')]
swi= data.loc[(data['Country'] == 'Switzerland') & (data['Date Joined'] > '1-1-2022')]
bel= data.loc[(data['Country'] == 'Belgium') & (data['Date Joined'] > '1-1-2022')]
fin= data.loc[(data['Country'] == 'Finland') & (data['Date Joined'] > '1-1-2022')]
Ir= data.loc[(data['Country'] == 'Ireland') & (data['Date Joined'] > '1-1-2022')]
Is= data.loc[(data['Country'] == 'Israel') & (data['Date Joined'] > '1-1-2022')]
Murica = len(US.index)
Cina = len(CN.index)
Britan = len(UK.index)
Inia = len(IND.index)
Inosia = len(IN.index)
Gerany = len(GER.index)
Sinapo = len(SIN.index)
Japa = len(JP.index)
Koea = len(SK.index)
Franc = len(FR.index)
SWD= len(Swe.index)
Ital= len(ITL.index)
CZE= len(CR.index)
NORAY=len(NOR.index)
MALAYA= len(MAL.index)
CROIA= len(cro.index)
PHIL= len(phi.index)
Luxo= len(lex.index)
Spai=len(spa.index)
Denma= len(den.index)
SWISS= len(swi.index)
BELGI= len(bel.index)
Finla= len(fin.index)
Irich= len(Ir.index)
Isa= len(Is.index)
y = [Murica, Cina, Britan, Inia, Inosia, Gerany, Sinapo, Japa, Koea, Franc]
y
x = ["US", "CN/HK", "UK", "Ind", "Indo", "Ger", "Sin", "Jp", "Kr", "Fr"]
x
plt.bar(x, y, color='maroon', width=0.4)
plt.tight_layout
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
USA.append(Murica)
China.append(Cina)
Britain.append(Britan)
India.append(Inia)
Indonesia.append(Inosia)
Germany.append(Gerany)
Sing.append(Sinapo)
Japan.append(Japa)
Korea.append(Koea)
France.append(Franc)
Pacific.append(Cina+Inia+Inosia+Sinapo+Japa+Koea+PHIL+MALAYA)
Europe.append(Britan+Gerany+NORAY+Franc+SWISS+Ital+CZE+Denma+Finla+Luxo+Spai+BELGI+CROIA+Irich)
Israel.append(Isa)

# %%
Year= [0, 1, 2, 3, 4]

plt.bar(Year, USA, label="USA")
plt.bar(Year,  Pacific, label="Indo-pacific", bottom=USA)
plt.xlabel("Years since 2018")
plt.ylabel("# of unicorns added")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Year= [2018, 2019, 2020, 2021, 2022]
X_axis = np.arange(len(Year))

plt.bar(X_axis - 0.2, USA, 0.4, label = 'USA')
plt.bar(X_axis + 0.2, Pacific, 0.4, label = 'Indo-pacific')
plt.xlabel("Years since 2018")
plt.ylabel("# of unicorns added")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Year= [2018, 2019, 2020, 2021, 2022]
X_axis = np.arange(len(Year))

plt.bar(X_axis - 0.2, Europe, 0.4, label = 'Europe')
plt.bar(X_axis + 0.2, Pacific, 0.4, label = 'Indo-pacific')
plt.xlabel("Years since 2018")
plt.ylabel("# of unicorns added")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Year= [0, 1, 2, 3, 4]

plt.bar(Year, Europe, label="Europe")
plt.bar(Year,  Pacific, label="Indo-pacific", bottom=Europe)
plt.xlabel("Years since 2018")
plt.ylabel("# of unicorns added")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Year= [2018, 2019, 2020, 2021, 2022]
X_axis = np.arange(len(Year))

plt.bar(X_axis - 0.2, China, 0.4, label = 'China')
plt.bar(X_axis + 0.2, India, 0.4, label = 'India')
plt.xlabel("Years since 2018")
plt.ylabel("# of unicorns added")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Year= [0, 1, 2, 3, 4]
x= list()

for i in range (0,5):
    x.append(Korea[i]+Sing[i])
plt.bar(X_axis + 0.2, Korea, 0.4, label = 'South Korea')
plt.bar(X_axis + 0.2, Sing, 0.4, label = 'Sinapore', bottom=Korea)
plt.bar(X_axis + 0.2, Japan, 0.4, label = 'Japan', bottom= x)

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Year= [2018, 2019, 2020, 2021, 2022]
X_axis = np.arange(len(Year))

plt.bar(X_axis - 0.2, Israel, 0.4, label = 'Israel')
plt.bar(X_axis + 0.2, Germany, 0.4, label = 'Germany')
plt.xlabel("Years since 2018")
plt.ylabel("# of unicorns added")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Year= [2018, 2019, 2020, 2021, 2022]
X_axis = np.arange(len(Year))

plt.bar(X_axis - 0.2, Israel, 0.4, label = 'Israel')
plt.bar(X_axis + 0.2, Korea, 0.4, label = 'South Korea')
plt.xlabel("Years since 2018")
plt.ylabel("# of unicorns added")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n = 6
d=data['City '].value_counts()
d1=d.head(n)
df=pd.DataFrame(d1)
df
# Out:
#                City
# San Francisco    168
# New York         111
# Beijing           62
# Shanghai          46
# London            36
# Bengaluru         31

# %%
xx=df.reset_index()
xx
# Out:
#            index  City
# 0  San Francisco    168
# 1       New York    111
# 2        Beijing     62
# 3       Shanghai     46
# 4         London     36
# 5      Bengaluru     31

# %%
x= xx['City ']
x
# Out:
# 0    168
# 1    111
# 2     62
# 3     46
# 4     36
# 5     31
# Name: City , dtype: int64

# %%
y = xx['index']
y
# Out:
# 0    San Francisco
# 1         New York
# 2          Beijing
# 3         Shanghai
# 4           London
# 5        Bengaluru
# Name: index, dtype: object

# %%
plt.bar(y, x, color='maroon', width=0.4)
plt.tight_layout
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
plt.bar("City Start-up Segment chart", x[0], label=y[0])
plt.bar("City Start-up Segment chart", x[1],bottom=x[0], label=y[1])
plt.bar("City Start-up Segment chart", x[2],bottom=x[0]+x[1], label=y[2])
plt.bar("City Start-up Segment chart", x[3],bottom=x[0]+x[1]+x[2], label=y[3])
plt.bar("City Start-up Segment chart", x[4],bottom=x[0]+x[1]+x[2]+x[3], label=y[4])
plt.bar("City Start-up Segment chart", x[5],bottom=x[0]+x[1]+x[2]+x[3]+x[4], label=y[5])
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
